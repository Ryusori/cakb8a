# %% [markdown]
# # 🤞12/5

# %% [markdown]
# ### pd.DataFrame

# %%
# 데이터 프레이 만들기 (1)

df1 = pd.DataFrame({'국어' : [80, 70],
                   '영어' : [90, 80],
                   '수학' : [100, 90]}, index = ['A', 'B']) 
df1
# Out:
#    국어  영어   수학
# A  80  90  100
# B  70  80   90

# %%
# 데이터 프레이 만들기 (2)

import pandas as pd

df = pd.DataFrame({' '   : ['국어', '영어', '수학'],
                   'A'   :   [80,90,100],
                   'B'    : [70,80,90]})
df.T
# Out:
#     0   1    2
#    국어  영어   수학
# A  80  90  100
# B  70  80   90

# %% [markdown]
# ## 열 추가

# %%
#과학 90,90 추가하기

df1['과학']= [90,90]
df1
# Out:
#    국어  영어   수학  과학
# A  80  90  100  90
# B  70  80   90  90

# %% [markdown]
# ### drop 열삭제

# %%
# 수학 과목 삭제하기

df1.drop(columns="수학",inplace=True)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-a5bd3845648a> in <module>
#       1 # 수학 과목 삭제하기
#       2
# ----> 3 df1.drop(columns="수학",inplace=True)
#       4 df1
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %% [markdown]
# ### 총점 열 추가

# %%
# 총점열을 만들어 값의 합을 적으시오.

df1["총점"]=df1["국어"] + df1["과학"] +df1["영어"]
df1
# Out:
#    국어  영어  과학   총점
# A  80  90  90  260
# B  70  80  90  240
# C  70  80  90  240

# %% [markdown]
# ### loc 행추가

# %%
# 행 이름이 c 70,80,90,240인 향을 추가합시다.

df1.loc['C'] = [70,80,90,240]
df1
# Out:
#    국어  영어  과학   총점
# A  80  90  90  NaN
# B  70  80  90  240
# C  70  80  90  240

# %% [markdown]
# ### np.nan 결측치만들기

# %%
# 총점의 260을 결측치로 만들어라.
import numpy as np
df1["총점"] = np.where(df1["총점"]==260,"NaN",df1["총점"])
df1
# Out:
#    국어  영어  과학   총점
# A  80  90  90  NaN
# B  70  80  90  240
# C  70  80  90  240

# %%
df1['총점'][0] = np.nan
df1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-3f361dc8e098> in <module>
# ----> 1 df1['총점'][0] = np.nan
#       2 df1
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %% [markdown]
# ### replace

# %%
df1['총점'].replace(260, "NaN", inplace=True) 
df1
# Out:
#    국어  영어  과학   총점
# A  80  90  90  NaN
# B  70  80  90  240
# C  70  80  90  240

# %% [markdown]
# ## 열의 이름바꾸기

# %%
df2=df1.copy()
df2
# Out:
#    국어  영어  과학   총점
# A  80  90  90  260
# B  70  80  90  240
# C  70  80  90  240

# %% [markdown]
# ### rename

# %%
# 총점으로 이름 바꾸기

df1.rename(columns={'총점': 'Total'})
# Out:
#    국어  영어  과학  Total
# A  80  90  90    260
# B  70  80  90    240
# C  70  80  90    240

# %% [markdown]
# ### np.where

# %%
# 총점이 250이상이면 A+, 그이하이면 A-

df1["학점"]= np.where(df1["총점"]>=250,"A+","A-")
df1
# Out:
#    국어  영어  과학   총점  학점
# A  80  90  90  260  A+
# B  70  80  90  240  A-
# C  70  80  90  240  A-

# %% [markdown]
# ### sort_values 오름차순

# %%
# 총점,국어 점수의 오름차순으로 정렬

df1.sort_values(by=["총점", '국어'])
# Out:
#    국어  영어  과학   총점  학점
# B  70  80  90  240  A-
# C  70  80  90  240  A-
# A  80  90  90  260  A+

# %% [markdown]
# ### mpg 파일 불러오기

# %%
import pydataset
mpg=pydataset.data("mpg")
mpg[:2]
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %%
# year은 모주 몊년이가?
import pandas as pd
pd.unique(mpg['year'])
# Out:
# array([1999, 2008])

# %% [markdown]
# ### groupby

# %%
# 연도별 cty의 평균은?
import numpy as np
mpg.groupby('year')['cty'].agg(np.mean)
# Out:
# year
# 1999    17.017094
# 2008    16.700855
# Name: cty, dtype: float64

# %%
# audi의 연도별 cty의 평균은?

mpg[mpg['manufacturer'] == 'audi'].groupby('year')['cty'].agg(np.mean)
# Out:
# year
# 1999    17.111111
# 2008    18.111111
# Name: cty, dtype: float64

# %% [markdown]
# # 🤞12/6

# %%
pip install pydataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.9 MB 5.3 MB/s
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939432 sha256=f317c9595613495615e6824ef07f205f7aaf247c335096ef1de030d33b5baffc
#   Stored in directory: /root/.cache/pip/wheels/d7/e5/36/85d319586b4a405d001029d489102f526ce5546248c295932a
# Successfully built pydataset
# ...

# %%
import pydataset
pydataset.data('mpg')
# Out:
# initiated datasets repo at: /root/.pydataset/
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# ### query

# %%
# f1이 p,r,e인것을 선택해라.
mpg.query("fl == ['p', 'r', 'e']")
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    category
# dtypes: category(1), float64(1), int64(4), object(5)
# memory usage: 20.7+ KB

# %% [markdown]
# ### astype 타입바꾸기

# %%
mpg['class'] = mpg['class'].astype('category')

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    category
# dtypes: category(1), float64(1), int64(4), object(5)
# memory usage: 20.7+ KB

# %%
# mpg["cty"]가 짝수이면 2더하고, 홀수면 1 더하고

import numpy as np
np.where(mpg["cty"]%2==0, mpg["cty"]+2,mpg["cty"]+1)
# Out:
# array([20, 22, 22, 22, 18, 20, 20, 20, 18, 22, 20, 16, 18, 18, 16, 16, 18,
#        18, 16, 12, 16, 14, 14, 18, 16, 18, 16, 16, 16, 12, 12, 16, 20, 24,
#        20, 20, 18, 20, 18, 18, 18, 18, 18, 12, 16, 16, 18, 18, 16, 16, 14,
#        16, 16, 16, 10, 12, 12, 14, 14, 10, 14, 12, 14, 12, 14, 10, 14, 14,
#        14, 10, 12, 12, 14, 12, 12, 12, 14, 16, 16, 16, 14, 14, 14, 16, 16,
#        14, 14, 14, 12, 14, 20, 20, 18, 18, 16, 16, 16, 16, 16, 30, 26, 26,
#        24, 26, 28, 26, 26, 22, 20, 20, 22, 22, 20, 20, 20, 20, 20, 22, 22,
#        18, 18, 18, 18, 16, 16, 16, 10, 16, 14, 12, 12, 14, 14, 12, 12, 12,
#        14, 16, 14, 14, 14, 22, 20, 24, 24, 20, 20, 20, 20, 20, 16, 16, 16,
#        14, 20, 18, 18, 20, 18, 20, 20, 22, 20, 22, 20, 22, 20, 20, 20, 22,
#        22, 20, 22, 16, 18, 16, 16, 18, 16, 22, 22, 22, 22, 20, 20, 20, 22,
#        22, 22, 24, 20, 20, 20, 26, 26, 28, 30, 28, 12, 14, 16, 18, 18, 16,
# ...

# %% [markdown]
# ### apply & lambda

# %%
mpg.cty.apply(lambda x:  x+2 if x%2 == 0 else x+1)
# Out:
# 1      20
# 2      22
# 3      22
# 4      22
# 5      18
#        ..
# 230    20
# 231    22
# 232    18
# 233    20
# 234    18
# Name: cty, Length: 234, dtype: int64

# %% [markdown]
# ### map & lambda

# %%
def add(x):
    if x % 2 == 0:
        x += 2
        return x
    else:
        x += 1
        return x

list(map(add,mpg["cty"]))

# %% [markdown]
# ### filter(참, 거짓) & lambda

# %%
mpg.hwy.describe()
# Out:
# count    234.000000
# mean      23.440171
# std        5.954643
# min       12.000000
# 25%       18.000000
# 50%       24.000000
# 75%       27.000000
# max       44.000000
# Name: hwy, dtype: float64

# %% [markdown]
# ### cut 구간나누기

# %%
# 구간나누기, 20a ,30b ,40c ,40이상d , rank열을 추가해주세요

bins = [0, 20, 30, 40, 100]
rank=["A","B","C","D"]
mpg["rank"] = pd.cut(mpg["hwy"], bins,labels=rank)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class rank
# 1    compact    B
# 2    compact    B
# 3    compact    C
# 4    compact    B
# ...

# %%
# mpg["trans"]에서 "auto" 만 뽑아 봅시다

mpg[mpg['trans'].str[:4] == 'auto']
# Out:
#     manufacturer                   model  displ  year  cyl     trans drv  cty  \
# 1           audi                      a4    1.8  1999    4  auto(l5)   f   18
# 4           audi                      a4    2.0  2008    4  auto(av)   f   21
# 5           audi                      a4    2.8  1999    6  auto(l5)   f   16
# 7           audi                      a4    3.1  2008    6  auto(av)   f   18
# 9           audi              a4 quattro    1.8  1999    4  auto(l5)   4   16
# 11          audi              a4 quattro    2.0  2008    4  auto(s6)   4   19
# 12          audi              a4 quattro    2.8  1999    6  auto(l5)   4   15
# 14          audi              a4 quattro    3.1  2008    6  auto(s6)   4   17
# 16          audi              a6 quattro    2.8  1999    6  auto(l5)   4   15
# 17          audi              a6 quattro    3.1  2008    6  auto(s6)   4   17
# 18          audi              a6 quattro    4.2  2008    8  auto(s6)   4   16
# ...

# %%
mpg[mpg['trans'].str.contains('auto')]
# Out:
#     manufacturer                   model  displ  year  cyl     trans drv  cty  \
# 1           audi                      a4    1.8  1999    4  auto(l5)   f   18
# 4           audi                      a4    2.0  2008    4  auto(av)   f   21
# 5           audi                      a4    2.8  1999    6  auto(l5)   f   16
# 7           audi                      a4    3.1  2008    6  auto(av)   f   18
# 9           audi              a4 quattro    1.8  1999    4  auto(l5)   4   16
# 11          audi              a4 quattro    2.0  2008    4  auto(s6)   4   19
# 12          audi              a4 quattro    2.8  1999    6  auto(l5)   4   15
# 14          audi              a4 quattro    3.1  2008    6  auto(s6)   4   17
# 16          audi              a6 quattro    2.8  1999    6  auto(l5)   4   15
# 17          audi              a6 quattro    3.1  2008    6  auto(s6)   4   17
# 18          audi              a6 quattro    4.2  2008    8  auto(s6)   4   16
# ...

# %% [markdown]
# # 🤞12/7

# %%
import pandas as pd
import pydataset
# Out:
# initiated datasets repo at: /root/.pydataset/

# %%
mpg=pydataset.data("mpg")
mpg[:2]
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %%
# fl을 fuel로 칼럼이름 바꾸기
mpg.rename(columns={'fl': 'fuel'}, inplace=True) 
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
# furl이 p,r,e인 mpg?

mpg.query("fuel==['p','r','e']")
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
mpg[mpg["fuel"].isin(['p','r','e'])]
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
# 제조사별로 연도별 cty의 평균
mpg.groupby(["year","manufacturer"]).mean()[["cty"]]
# Out:
#                          cty
# year manufacturer
# 1999 audi          17.111111
#      chevrolet     15.142857
#      dodge         13.375000
#      ford          13.933333
#      honda         24.800000
#      hyundai       18.333333
#      jeep          14.500000
#      land rover    11.000000
#      lincoln       11.000000
#      mercury       13.500000
#      nissan        17.666667
#      pontiac       17.000000
#      subaru        19.000000
#      toyota        18.150000
#      volkswagen    21.250000
# 2008 audi          18.111111
#      chevrolet     14.916667
#      dodge         12.952381
#      ford          14.100000
#      honda         24.000000
#      hyundai       18.875000
#      jeep          13.166667
#      land rover    12.000000
#      lincoln       12.000000
#      mercury       13.000000
#      nissan        18.428571
#      pontiac       17.000000
#      subaru        19.500000
#      toyota        19.071429
#      volkswagen    20.454545

# %% [markdown]
# ### groupby 의 순서
# - split 분리
# - apply 적용
# - combine 합치다

# %%
# 제조사별로 연도별 cty의 평균,hwy의 최댓값

mpg.groupby(["year","manufacturer"])[["cty","hwy"]].agg({"cty":'mean',"hwy":'max'})
# Out:
#                          cty  hwy
# year manufacturer
# 1999 audi          17.111111   29
#      chevrolet     15.142857   27
#      dodge         13.375000   24
#      ford          13.933333   26
#      honda         24.800000   33
#      hyundai       18.333333   29
#      jeep          14.500000   20
#      land rover    11.000000   15
#      lincoln       11.000000   17
#      mercury       13.500000   17
#      nissan        17.666667   29
#      pontiac       17.000000   27
#      subaru        19.000000   26
#      toyota        18.150000   35
#      volkswagen    21.250000   44
# 2008 audi          18.111111   31
#      chevrolet     14.916667   30
#      dodge         12.952381   24
#      ford          14.100000   26
#      honda         24.000000   36
#      hyundai       18.875000   31
#      jeep          13.166667   22
#      land rover    12.000000   18
#      lincoln       12.000000   18
#      mercury       13.000000   19
#      nissan        18.428571   32
# ...

# %% [markdown]
# ### pivot_table

# %%
# 제조사, 모델,cty의 pivot표!
mpg.pivot_table(index="manufacturer",columns="year",values="cty")
# Out:
# year               1999       2008
# manufacturer
# audi          17.111111  18.111111
# chevrolet     15.142857  14.916667
# dodge         13.375000  12.952381
# ford          13.933333  14.100000
# honda         24.800000  24.000000
# hyundai       18.333333  18.875000
# jeep          14.500000  13.166667
# land rover    11.000000  12.000000
# lincoln       11.000000  12.000000
# mercury       13.500000  13.000000
# nissan        17.666667  18.428571
# pontiac       17.000000  17.000000
# subaru        19.000000  19.500000
# toyota        18.150000  19.071429
# volkswagen    21.250000  20.454545

# %% [markdown]
# ### sample

# %%
# mpg 50%만 samepling 해 주세요.
mpg_1 = mpg.sample(frac=0.5, random_state=1111) 
mpg_1
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 220   volkswagen                   jetta    2.8  1999    6    auto(l4)   f
# 34     chevrolet                  malibu    2.4  2008    4    auto(l4)   f
# 213   volkswagen                   jetta    1.9  1999    4  manual(m5)   f
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 69         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 120      hyundai                 tiburon    2.7  2008    6    auto(l4)   f
# 224   volkswagen              new beetle    2.0  1999    4  manual(m5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 67         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 84          ford         f150 pickup 4wd    4.2  1999    6    auto(l4)   4
# 203       toyota       toyota tacoma 4wd    2.7  2008    4  manual(m5)   4
# ...

# %% [markdown]
# ## 차집합 isin,drop,any

# %%
# mpg-mpg_1의 차집합 구하기.
mpg[mpg.index.isin(mpg_1.index) == False]
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# ...

# %%
mpg[mpg.isin(mpg_1).any(axis=1)]
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# 13          audi              a4 quattro    2.8  1999    6  manual(m5)   4
# 14          audi              a4 quattro    3.1  2008    6    auto(s6)   4
# 17          audi              a6 quattro    3.1  2008    6    auto(s6)   4
# 18          audi              a6 quattro    4.2  2008    8    auto(s6)   4
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# ...

# %%
mpg.drop(mpg_1.index, axis=0)
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# ...

# %%
# mpg에서 manufacturer/model/drv 로 info 칼럼을 만들어주세여

manuf = mpg.manufacturer.values
model = mpg.model.values
drv = mpg.drv.values

info = list(zip(manuf, model, drv))

mpg['info'] = info
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class                     info
# 1    compact            (audi, a4, f)
# ...

# %%
mpg['info'] = mpg['manufacturer'] + '/' + mpg['model'] + '/' + mpg['drv'] 
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fuel  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29    p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29    p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31    p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30    p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26    p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ...  ...
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28    p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29    p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26    p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26    p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26    p
#
#        class                 info
# 1    compact            audi/a4/f
# ...

# %% [markdown]
# # 🤞 12/8

# %%
pip install pydataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.9 MB 5.1 MB/s
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939432 sha256=3a1048556400dab0bdb546320d3a0f97a678c5cd9a9f15e94164321079e29127
#   Stored in directory: /root/.cache/pip/wheels/d7/e5/36/85d319586b4a405d001029d489102f526ce5546248c295932a
# Successfully built pydataset
# ...

# %%
import pandas as pd
import pydataset

mpg = pydataset.data("mpg")
mpg[:2]
# Out:
# initiated datasets repo at: /root/.pydataset/
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %%
mpg1 = mpg.sample(n=100, random_state=1234)
mpg1
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 105        honda                   civic    1.8  2008    4  manual(m5)   f
# 209   volkswagen                     gti    2.0  1999    4    auto(l4)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 112      hyundai                  sonata    2.4  2008    4  manual(m5)   f
# 52         dodge       dakota pickup 4wd    3.9  1999    6  manual(m5)   4
# 224   volkswagen              new beetle    2.0  1999    4  manual(m5)   f
# 32     chevrolet         k1500 tahoe 4wd    6.5  1999    8    auto(l4)   4
# 93          ford                 mustang    4.0  2008    6  manual(m5)   r
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 131   land rover             range rover    4.0  1999    8    auto(l4)   4
# 111      hyundai                  sonata    2.4  2008    4    auto(l4)   f
# ...

# %%
# mpg2 = mpg-mpg1

mpg2=mpg.drop(index=mpg1.index,axis=0)
mpg2
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# 14          audi              a4 quattro    3.1  2008    6    auto(s6)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 17          audi              a6 quattro    3.1  2008    6    auto(s6)   4
# ...

# %% [markdown]
# ### concat : 데이터 합치기

# %%
# 복구하려면 , mpg = mpg1 + mpg2
sample =df.무게
s_m = (sample<130)

# Z검증통계량
z =(s_m -130)/ np.sqrt(9/14) #모분산은 n으로 나눠준다.
print(z)

# 임계값
rv= stats.norm()
rv.isf(0.95) # 생돈함수의 역함수, 생돈함수 =1-누적분포함수
print(z)

# p값
rv.cdf(z)

# %%
mpg3 = mpg.sample(frac=0.7, random_state= 1234)

# %% [markdown]
# ### concat , drop_duplicates() : 중복 제거

# %%
# mpg3과 겹치지 않도록 만들어라.

mpg4 = pd.concat([mpg1, mpg3], ignore_index=False).drop_duplicates() 
mpg4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159 entries, 105 to 134
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  159 non-null    object
#  1   model         159 non-null    object
#  2   displ         159 non-null    float64
#  3   year          159 non-null    int64
#  4   cyl           159 non-null    int64
#  5   trans         159 non-null    object
#  6   drv           159 non-null    object
#  7   cty           159 non-null    int64
#  8   hwy           159 non-null    int64
#  9   fl            159 non-null    object
#  10  class         159 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 14.9+ KB

# %%
mpg1 =mpg[:5]
mpg3=mpg[3:7]
mpg1.merge(mpg3,how="outer")
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
# 5         audi    a4    2.8  1999    6  manual(m5)   f   18   26  p  compact
# 6         audi    a4    3.1  2008    6    auto(av)   f   18   27  p  compact

# %%
mpg = pydataset.data("mpg")
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg['info'] = mpg['manufacturer'] + '/' + mpg['model'] + '/' + mpg['drv'] 
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class                 info
# 1    compact            audi/a4/f
# ...

# %% [markdown]
# ### drop 열삭제

# %%
# manufacturer,model,drv 삭제하기

mpg.drop(columns = ['manufacturer', 'model', 'drv'], inplace = True)
mpg
# Out:
#      displ  year  cyl       trans  cty  hwy fl    class                 info
# 1      1.8  1999    4    auto(l5)   18   29  p  compact            audi/a4/f
# 2      1.8  1999    4  manual(m5)   21   29  p  compact            audi/a4/f
# 3      2.0  2008    4  manual(m6)   20   31  p  compact            audi/a4/f
# 4      2.0  2008    4    auto(av)   21   30  p  compact            audi/a4/f
# 5      2.8  1999    6    auto(l5)   16   26  p  compact            audi/a4/f
# ..     ...   ...  ...         ...  ...  ... ..      ...                  ...
# 230    2.0  2008    4    auto(s6)   19   28  p  midsize  volkswagen/passat/f
# 231    2.0  2008    4  manual(m6)   21   29  p  midsize  volkswagen/passat/f
# 232    2.8  1999    6    auto(l5)   16   26  p  midsize  volkswagen/passat/f
# 233    2.8  1999    6  manual(m5)   18   26  p  midsize  volkswagen/passat/f
# 234    3.6  2008    6    auto(s6)   17   26  p  midsize  volkswagen/passat/f
#
# [234 rows x 9 columns]

# %% [markdown]
# ### .str.split('/') :기준으로 짜른다.

# %% [markdown]
# ### get()

# %%
# mpg[info] 에서 삭제했던 칼럼들 만들어 주기

slice_1=mpg['info'].str.split('/')
mpg['manufacturer']=slice_1.str.get(0)
mpg['model']=slice_1.str.get(1)
mpg['drv']=slice_1.str.get(2)
mpg
# Out:
#      displ  year  cyl       trans  cty  hwy fl    class                 info  \
# 1      1.8  1999    4    auto(l5)   18   29  p  compact            audi/a4/f
# 2      1.8  1999    4  manual(m5)   21   29  p  compact            audi/a4/f
# 3      2.0  2008    4  manual(m6)   20   31  p  compact            audi/a4/f
# 4      2.0  2008    4    auto(av)   21   30  p  compact            audi/a4/f
# 5      2.8  1999    6    auto(l5)   16   26  p  compact            audi/a4/f
# ..     ...   ...  ...         ...  ...  ... ..      ...                  ...
# 230    2.0  2008    4    auto(s6)   19   28  p  midsize  volkswagen/passat/f
# 231    2.0  2008    4  manual(m6)   21   29  p  midsize  volkswagen/passat/f
# 232    2.8  1999    6    auto(l5)   16   26  p  midsize  volkswagen/passat/f
# 233    2.8  1999    6  manual(m5)   18   26  p  midsize  volkswagen/passat/f
# 234    3.6  2008    6    auto(s6)   17   26  p  midsize  volkswagen/passat/f
#
#     manufacturer   model drv
# ...

# %%
for i in range(1,3):
    mpg['manufacturer']=mpg['info'].str.split('/')[i][0]
    mpg['model']=mpg['info'].str.split('/')[i][1]
    mpg['drv']=mpg['info'].str.split('/')[i][2]

# %% [markdown]
# ### enumerate : for문 돌리기

# %%
for i, [a,b,c] in enumerate(mpg['info'].str.split('/')):
    mpg['manufacturer'][i]=a
    mpg['model'][i]=b
    mpg['drv'][i]=c 
mpg
# Out:
# <ipython-input-29-605a48c2e7b7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mpg['manufacturer'][i]=a
# <ipython-input-29-605a48c2e7b7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mpg['model'][i]=b
# <ipython-input-29-605a48c2e7b7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mpg['drv'][i]=c
#      displ  year  cyl       trans  cty  hwy fl    class                 info  \
# ...

# %%
info_split = mpg['info'].str.split('/')
mpg['manufacturer'] = [x[0] for x in info_split]
mpg['model'] = [x[1] for x in info_split]
mpg['drv'] = [x[2] for x in info_split]
mpg
# Out:
#      displ  year  cyl       trans  cty  hwy fl    class                 info  \
# 1      1.8  1999    4    auto(l5)   18   29  p  compact            audi/a4/f
# 2      1.8  1999    4  manual(m5)   21   29  p  compact            audi/a4/f
# 3      2.0  2008    4  manual(m6)   20   31  p  compact            audi/a4/f
# 4      2.0  2008    4    auto(av)   21   30  p  compact            audi/a4/f
# 5      2.8  1999    6    auto(l5)   16   26  p  compact            audi/a4/f
# ..     ...   ...  ...         ...  ...  ... ..      ...                  ...
# 230    2.0  2008    4    auto(s6)   19   28  p  midsize  volkswagen/passat/f
# 231    2.0  2008    4  manual(m6)   21   29  p  midsize  volkswagen/passat/f
# 232    2.8  1999    6    auto(l5)   16   26  p  midsize  volkswagen/passat/f
# 233    2.8  1999    6  manual(m5)   18   26  p  midsize  volkswagen/passat/f
# 234    3.6  2008    6    auto(s6)   17   26  p  midsize  volkswagen/passat/f
#
#     manufacturer   model drv
# ...

# %%
mpg['info'].str.split('/', expand=True)
# Out:
#               0       1  2
# 1          audi      a4  f
# 2          audi      a4  f
# 3          audi      a4  f
# 4          audi      a4  f
# 5          audi      a4  f
# ..          ...     ... ..
# 230  volkswagen  passat  f
# 231  volkswagen  passat  f
# 232  volkswagen  passat  f
# 233  volkswagen  passat  f
# 234  volkswagen  passat  f
#
# [234 rows x 3 columns]

# %%
# trans가 'manual'인것만 

mpg[mpg["trans"].isin(['manual'])]
# Out:
# Empty DataFrame
# Columns: [displ, year, cyl, trans, cty, hwy, fl, class, info, manufacturer, model, drv]
# Index: []

# %% [markdown]
# ### str.contains

# %%
# trans가 'manual'인것만 
mpg[mpg['trans'].str.contains('manual')]
# Out:
#      displ  year  cyl       trans  cty  hwy fl       class  \
# 2      1.8  1999    4  manual(m5)   21   29  p     compact
# 3      2.0  2008    4  manual(m6)   20   31  p     compact
# 6      2.8  1999    6  manual(m5)   18   26  p     compact
# 8      1.8  1999    4  manual(m5)   18   26  p     compact
# 10     2.0  2008    4  manual(m6)   20   28  p     compact
# 13     2.8  1999    6  manual(m5)   17   25  p     compact
# 15     3.1  2008    6  manual(m6)   15   25  p     compact
# 24     5.7  1999    8  manual(m6)   16   26  p     2seater
# 26     6.2  2008    8  manual(m6)   16   26  p     2seater
# 28     7.0  2008    8  manual(m6)   15   24  p     2seater
# 49     3.7  2008    6  manual(m6)   15   19  r      pickup
# 52     3.9  1999    6  manual(m5)   14   17  r      pickup
# 56     5.2  1999    8  manual(m5)   11   17  r      pickup
# 65     4.7  2008    8  manual(m6)   12   16  r      pickup
# 69     4.7  2008    8  manual(m6)   12   16  r      pickup
# ...

# %% [markdown]
# # 12/9

# %%
# 8-7) 강아지 vs. 고양이 분류를 위한 소규모 컨브넷 만들기

from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         590080
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 1)                 12545
#
# ...

# %%
# 8-8) 모델 훈련 설정하기

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
# 8-6) 이미지를 훈련, 검증, 테스트 디렉토리로 복사하기

import os, shutil, pathlib

original_dir = pathlib.Path("/content/drive/MyDrive/과제2/cat_dog")
new_base_dir = pathlib.Path("/content/drive/MyDrive/과제2/cat_dog/train")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %%
# 8-9) 데이터 전처리image_dataset_from_directory를 사용하여 이미지 읽기

from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(  # 사진을 가져와라 함수수
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)

validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),

    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bfe71eeb7c3b> in <module>
#       4
#       5 train_dataset = image_dataset_from_directory(  # 사진을 가져와라 함수수
# ----> 6     new_base_dir / "train",
#       7     image_size=(180, 180),
#       8     batch_size=32)
#
# NameError: name 'new_base_dir' is not defined

# %%
# !pip install gdown

# %%
import gdown
url = "https://drive.google.com/uc?id=1ipzN9okFFT3oieklsrfr6iUHzjPAbT9i"
gdown.download(url, "cats_and_dogs.tar")

# %%
# !tar -xvf cats_and_dogs.tar
